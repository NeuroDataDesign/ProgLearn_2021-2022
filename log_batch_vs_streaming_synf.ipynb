# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import seaborn as sns
import numpy as np
import ast
from plotting import plot_error, load_data, get_mean_te, load_result

# %% [markdown]
# $$\text{LE}^t_n(f) := \frac{\mathbb{E}[R^t(f(\mathbf{S}^{t}_n))]}{\mathbb{E}[R^t(f(\mathbf{S}_n))]}$$

# %%
rxor_mean_errors, xnor_mean_errors, rxor_single_task_errors, xnor_single_task_errors = load_data()
r_xor_transfer_efficiencies = get_mean_te(rxor_mean_errors, rxor_single_task_errors)
xnor_transfer_efficiencies = get_mean_te(xnor_mean_errors, xnor_single_task_errors)

# %%
plot_error(np.array(rxor_mean_errors), "RXOR", np.log(r_xor_transfer_efficiencies))

# %%
plot_error(np.array(xnor_mean_errors), "XNOR", np.log(xnor_transfer_efficiencies))
